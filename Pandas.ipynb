# %%
import pandas as pd

df = pd.read_csv("BankMarketing.csv")

df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact      date  duration  campaign  pdays  previous poutcome Purchased?
# 0  unknown  5/5/2017       261         1     -1         0  unknown         no
# 1  unknown  5/5/2017       151         1     -1         0  unknown         no
# 2  unknown  5/5/2017        76         1     -1         0  unknown         no
# 3  unknown  5/5/2017        92         1     -1         0  unknown         no
# 4  unknown  5/5/2017       198         1     -1         0  unknown         no

# %%
df.shape
# Out:
# (45211, 16)

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'date', 'duration', 'campaign', 'pdays', 'previous',
#        'poutcome', 'Purchased?'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age            int64
# job           object
# marital       object
# education     object
# default       object
# balance        int64
# housing       object
# loan          object
# contact       object
# date          object
# duration       int64
# campaign       int64
# pdays          int64
# previous       int64
# poutcome      object
# Purchased?    object
# dtype: object

# %%
df.dtypes == "object"
# Out:
# age           False
# job            True
# marital        True
# education      True
# default        True
# balance       False
# housing        True
# loan           True
# contact        True
# date           True
# duration      False
# campaign      False
# pdays         False
# previous      False
# poutcome       True
# Purchased?     True
# dtype: bool

# %%
a = df.dtypes[df.dtypes == "object"].index
a
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'date', 'poutcome', 'Purchased?'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 age        balance      duration      campaign         pdays  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058    258.163080      2.763841     40.197828
# std       10.618762    3044.765829    257.527812      3.098021    100.128746
# min       18.000000   -8019.000000      0.000000      1.000000     -1.000000
# 25%       33.000000      72.000000    103.000000      1.000000     -1.000000
# 50%       39.000000     448.000000    180.000000      2.000000     -1.000000
# 75%       48.000000    1428.000000    319.000000      3.000000     -1.000000
# max       95.000000  102127.000000   4918.000000     63.000000    871.000000
#
#            previous
# count  45211.000000
# mean       0.580323
# std        2.303441
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      275.000000

# %%
df.isnull().sum()
# Out:
# age           0
# job           0
# marital       0
# education     0
# default       0
# balance       0
# housing       0
# loan          0
# contact       0
# date          0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# Purchased?    0
# dtype: int64

# %%
df.rename(columns={'Purchased?': 'purchased'}, inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'date', 'duration', 'campaign', 'pdays', 'previous',
#        'poutcome', 'purchased'],
#       dtype='object')

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact       date  duration  campaign  pdays  previous poutcome purchased
# 0  unknown 2017-05-05       261         1     -1         0  unknown        no
# 1  unknown 2017-05-05       151         1     -1         0  unknown        no
# 2  unknown 2017-05-05        76         1     -1         0  unknown        no
# 3  unknown 2017-05-05        92         1     -1         0  unknown        no
# 4  unknown 2017-05-05       198         1     -1         0  unknown        no

# %%
df[df['age'] > 40]
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 7       42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 8       58       retired   married    primary      no      121     yes   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45204   73       retired   married  secondary      no     2850      no   no
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
#
#          contact       date  duration  campaign  pdays  previous poutcome  \
# 0        unknown 2017-05-05       261         1     -1         0  unknown
# 1        unknown 2017-05-05       151         1     -1         0  unknown
# 3        unknown 2017-05-05        92         1     -1         0  unknown
# 7        unknown 2017-05-05       380         1     -1         0  unknown
# 8        unknown 2017-05-05        50         1     -1         0  unknown
# ...          ...        ...       ...       ...    ...       ...      ...
# 45204   cellular 2019-11-17       300         1     40         8  failure
# 45206   cellular 2019-11-17       977         3     -1         0  unknown
# 45207   cellular 2019-11-17       456         2     -1         0  unknown
# 45208   cellular 2019-11-17      1127         5    184         3  success
# 45209  telephone 2019-11-17       508         4     -1         0  unknown
#
#       purchased
# 0            no
# 1            no
# 3            no
# 7            no
# 8            no
# ...         ...
# 45204       yes
# 45206       yes
# 45207       yes
# 45208       yes
# 45209        no
#
# [20494 rows x 16 columns]

# %%
df[(df['age'] > 40) & (df['balance'] > 2000)]
# Out:
#        age          job   marital  education default  balance housing loan  \
# 0       58   management   married   tertiary      no     2143     yes   no
# 34      51   management   married   tertiary      no    10635     yes   no
# 40      44     services  divorced  secondary      no     2586     yes   no
# 65      51   management   married   tertiary      no     6530     yes   no
# 70      57  blue-collar   married  secondary      no     5935     yes  yes
# ...    ...          ...       ...        ...     ...      ...     ...  ...
# 45181   46  blue-collar   married  secondary      no     6879      no   no
# 45185   60     services   married   tertiary      no     4256     yes   no
# 45191   75      retired  divorced   tertiary      no     3810     yes   no
# 45204   73      retired   married  secondary      no     2850      no   no
# 45208   72      retired   married  secondary      no     5715      no   no
#
#         contact       date  duration  campaign  pdays  previous poutcome  \
# 0       unknown 2017-05-05       261         1     -1         0  unknown
# 34      unknown 2017-05-05       336         1     -1         0  unknown
# 40      unknown 2017-05-05       160         1     -1         0  unknown
# 65      unknown 2017-05-05        91         1     -1         0  unknown
# 70      unknown 2017-05-05       258         1     -1         0  unknown
# ...         ...        ...       ...       ...    ...       ...      ...
# 45181  cellular 2019-11-15        74         2    118         3  failure
# 45185  cellular 2019-11-16       200         1     92         4  success
# 45191  cellular 2019-11-16       262         1    183         1  failure
# 45204  cellular 2019-11-17       300         1     40         8  failure
# 45208  cellular 2019-11-17      1127         5    184         3  success
#
#       purchased
# 0            no
# 34           no
# 40           no
# 65           no
# 70           no
# ...         ...
# 45181        no
# 45185       yes
# 45191       yes
# 45204       yes
# 45208       yes
#
# [4558 rows x 16 columns]

# %%
df[['age', 'job', 'balance', 'purchased']]
# Out:
#        age           job  balance purchased
# 0       58    management     2143        no
# 1       44    technician       29        no
# 2       33  entrepreneur        2        no
# 3       47   blue-collar     1506        no
# 4       33       unknown        1        no
# ...    ...           ...      ...       ...
# 45206   51    technician      825       yes
# 45207   71       retired     1729       yes
# 45208   72       retired     5715       yes
# 45209   57   blue-collar      668        no
# 45210   37  entrepreneur     2971        no
#
# [45211 rows x 4 columns]

# %%
df['balance_category'] = df['balance'].apply(
    lambda x: 'Low' if x < 1000 else 'Medium' if x < 5000 else 'High'
)

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact       date  duration  campaign  pdays  previous poutcome purchased  \
# 0  unknown 2017-05-05       261         1     -1         0  unknown        no
# 1  unknown 2017-05-05       151         1     -1         0  unknown        no
# 2  unknown 2017-05-05        76         1     -1         0  unknown        no
# 3  unknown 2017-05-05        92         1     -1         0  unknown        no
# 4  unknown 2017-05-05       198         1     -1         0  unknown        no
#
#   balance_category
# 0           Medium
# 1              Low
# 2              Low
# 3           Medium
# 4              Low

# %%
df.groupby('job')['balance'].mean()
# Out:
# job
# admin.           1135.838909
# blue-collar      1078.826654
# entrepreneur     1521.470074
# housemaid        1392.395161
# management       1763.616832
# retired          1984.215106
# self-employed    1647.970868
# services          997.088108
# student          1388.060768
# technician       1252.632092
# unemployed       1521.745971
# unknown          1772.357639
# Name: balance, dtype: float64

# %%
import numpy as np
import pandas as pd

labels = ['a','b','c']
my_data = [10,20,30]
arr = np.array(my_data)
d = {'a':10,'b':20,'c':30}

print ("Labels:", labels)
print("My data:", my_data)
print(arr)
print("Dictionary:", d)
# Out:
# Labels: ['a', 'b', 'c']
# My data: [10, 20, 30]
# [10 20 30]
# Dictionary: {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(my_data, index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
print ("\nHolding numerical data\n",'-'*25, sep='')
print(pd.Series(arr)[0])
# Out:
# Holding numerical data
# -------------------------
# 10

# %%
print ("\nHolding text labels\n",'-'*20, sep='')
print(pd.Series(labels))
# Out:
# Holding text labels
# --------------------
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
ser1 = pd.Series([1,2,3,4],index = [2,4,6,8])
ser1
# Out:
# 2    1
# 4    2
# 6    3
# 8    4
# dtype: int64

# %%
ser2 = pd.Series([1,2,5,4],['CA', 'OR', 'NV', 'AZ'])
ser2
# Out:
# CA    1
# OR    2
# NV    5
# AZ    4
# dtype: int64

# %%
print ("\nIndexing by number (positional value in the series)\n",'-'*52, sep='')
print("Value for CA in ser1:", ser1[2])
print("Value for AZ in ser1:", ser1[4])
print("Value for NV in ser2:", ser2['NV'])
# Out:
# Indexing by number (positional value in the series)
# ----------------------------------------------------
# Value for CA in ser1: 1
# Value for AZ in ser1: 2
# Value for NV in ser2: 5

# %%
ser1 = pd.Series([1,2,3,4],['CA', 'OR', 'CO', 'CA'])
ser2 = pd.Series([1,2,5,4],['CA', 'NV', 'AZ','OR'])
ser3 = ser1+ser2
ser3
# Out:
# AZ    NaN
# CA    2.0
# CA    5.0
# CO    NaN
# NV    NaN
# OR    6.0
# dtype: float64

# %%
from numpy.random import randn as rn
np.random.seed(101)
matrix_data = rn(5,4)
matrix_data
row_labels = ['A','B','C','D','E']
column_headings = ['W','X','Y','Z']

df = pd.DataFrame(matrix_data,row_labels,column_headings)
print("\nThe data frame looks like\n",'-'*45, sep='')
df
# Out:
# The data frame looks like
# ---------------------------------------------
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.iloc[0]
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %%
df.loc['C','W']
# Out:
# np.float64(-2.018168244037392)

# %%
print("\nA column is created by assigning it in relation to an existing column\n",'-'*75, sep='')
df['New'] = df['X']+df['Z']
df['New (Sum of X and Z)'] = df['X']+df['Z']
print(df)
# Out:
# A column is created by assigning it in relation to an existing column
# ---------------------------------------------------------------------------
#           W         X         Y         Z       New  New (Sum of X and Z)
# A  2.706850  0.628133  0.907969  0.503826  1.131958              1.131958
# B  0.651118 -0.319318 -0.848077  0.605965  0.286647              0.286647
# C -2.018168  0.740122  0.528813 -0.589001  0.151122              0.151122
# D  0.188695 -0.758872 -0.933237  0.955057  0.196184              0.196184
# E  0.190794  1.978757  2.605967  0.683509  2.662266              2.662266

# %%
print("\nA column is dropped by using df.drop() method\n",'-'*55, sep=' ')
df.drop("A",inplace=True) # Notice the axis=1 option, axis = 0 is default, so one has to change it to 1
# Out:
# A column is dropped by using df.drop() method
#  -------------------------------------------------------

# %%
df
# Out:
#           W         X         Y         Z       New  New (Sum of X and Z)
# B  0.651118 -0.319318 -0.848077  0.605965  0.286647              0.286647
# C -2.018168  0.740122  0.528813 -0.589001  0.151122              0.151122
# D  0.188695 -0.758872 -0.933237  0.955057  0.196184              0.196184
# E  0.190794  1.978757  2.605967  0.683509  2.662266              2.662266

# %%
import pandas as pd 
import numpy as np
matrix_data = np.matrix('22,66,140;42,70,148;30,62,125;35,68,160;25,62,152')
row_labels = ['A','B','C','D','E']
column_headings = ['Age', 'Height', 'Weight']
matrix_data
# Out:
# matrix([[ 22,  66, 140],
#         [ 42,  70, 148],
#         [ 30,  62, 125],
#         [ 35,  68, 160],
#         [ 25,  62, 152]])

# %%
df = pd.DataFrame(data=matrix_data, index=row_labels, columns=column_headings)
print("\nA new DataFrame\n",'-'*25, sep='')
print(df)
# Out:
# A new DataFrame
# -------------------------
#    Age  Height  Weight
# A   22      66     140
# B   42      70     148
# C   30      62     125
# D   35      68     160
# E   25      62     152

# %%
print("\nRows with Height > 65 inch\n",'-'*35, sep='')
print(df[df['Height']>65])
# Out:
# Rows with Height > 65 inch
# -----------------------------------
#    Age  Height  Weight
# A   22      66     140
# B   42      70     148
# D   35      68     160

# %%
matrix_data = np.matrix('22,66,140;42,70,148;30,62,125;35,68,160;25,62,152')
row_labels = ['A','B','C','D','E']
column_headings = ['Age', 'Height', 'Weight']

# %%
df = pd.DataFrame(data=matrix_data, index=row_labels, columns=column_headings)
print("\nThe DataFrame\n",'-'*25, sep='')
print(df)
# Out:
# The DataFrame
# -------------------------
#    Age  Height  Weight
# A   22      66     140
# B   42      70     148
# C   30      62     125
# D   35      68     160
# E   25      62     152

# %%
print("\nAfter resetting index\n",'-'*35, sep='')
print(df.reset_index())
# Out:
# After resetting index
# -----------------------------------
#   index  Age  Height  Weight
# 0     A   22      66     140
# 1     B   42      70     148
# 2     C   30      62     125
# 3     D   35      68     160
# 4     E   25      62     152

# %%
print("\nAfter resetting index with 'drop' option TRUE\n",'-'*45, sep='')
print(df.reset_index(drop=True))
"Student Teacher Engineer Doctor Nurse".split()
# Out:
# After resetting index with 'drop' option TRUE
# ---------------------------------------------
#    Age  Height  Weight
# 0   22      66     140
# 1   42      70     148
# 2   30      62     125
# 3   35      68     160
# 4   25      62     152
# ['Student', 'Teacher', 'Engineer', 'Doctor', 'Nurse']

# %%
print("\nAdding a new column 'Profession'\n",'-'*45, sep='')
df['Profession'] = "Student Teacher Engineer Doctor Nurse".split()
print(df)
# Out:
# Adding a new column 'Profession'
# ---------------------------------------------
#    Age  Height  Weight Profession
# A   22      66     140    Student
# B   42      70     148    Teacher
# C   30      62     125   Engineer
# D   35      68     160     Doctor
# E   25      62     152      Nurse

# %%
print("\nSetting 'Profession' column as index\n",'-'*45, sep='')
print (df.set_index('Profession'))
# Out:
# Setting 'Profession' column as index
# ---------------------------------------------
#             Age  Height  Weight
# Profession
# Student      22      66     140
# Teacher      42      70     148
# Engineer     30      62     125
# Doctor       35      68     160
# Nurse        25      62     152
